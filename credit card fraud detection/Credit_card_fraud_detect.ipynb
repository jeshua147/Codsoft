# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv('fraudTrain.csv')
df.head(5)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
df.dropna(ignore_index=True, inplace=True)

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

df['dob'] = pd.to_datetime(df['dob'])
df['hour'] = df['trans_date_trans_time'].dt.hour
df['is_night'] = df['hour'].apply(lambda x: 1 if x < 6 or x > 22 else 0)
df['day_of_week'] = df['trans_date_trans_time'].dt.dayofweek

# %%
df.head(3)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
#
#                           merchant       category     amt      first     last  \
# 0       fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer    Banks
# 1  fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie     Gill
# 2             fraud_Lind-Buckridge  entertainment  220.11     Edward  Sanchez
#
#   gender                        street  ...  \
# 0      F                561 Perry Cove  ...
# 1      F  43039 Riley Greens Suite 393  ...
# 2      M      594 White Dale Suite 530  ...
#
#                                  job        dob  \
# 0          Psychologist, counselling 1988-03-09
# 1  Special educational needs teacher 1978-06-21
# 2        Nature conservation officer 1962-01-19
#
# ...

# %%
df.drop(columns=['Unnamed: 0','cc_num','first','last','street','city','state','zip','dob','unix_time','trans_num'],
        inplace=True)

# %%
from haversine import haversine
def compute_distance(row):
    return haversine((row['lat'], row['long']), (row['merch_lat'], row['merch_long']))

df['distance'] = df.apply(compute_distance, axis=1)
df.drop(['trans_date_trans_time','lat', 'long', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# %%
encoder = LabelEncoder()
df["merchant"] = encoder.fit_transform(df["merchant"])
df["category"] = encoder.fit_transform(df["category"])
df["gender"] = encoder.fit_transform(df["gender"])
df["job"] = encoder.fit_transform(df["job"])

# %%
df.head(5)
# Out:
#    merchant  category     amt  gender  city_pop  job  is_fraud  hour  \
# 0       514         8    4.97       0      3495  370         0     0
# 1       241         4  107.23       0       149  428         0     0
# 2       390         0  220.11       1      4154  307         0     0
# 3       360         2   45.00       1      1939  328         0     0
# 4       297         9   41.96       1        99  116         0     0
#
#    is_night  day_of_week    distance
# 0         1            1   78.597677
# 1         1            1   30.212217
# 2         1            1  108.206232
# 3         1            1   95.673363
# 4         1            1   77.556851

# %%
X = df.drop(columns=["is_fraud"], inplace = False)
Y = df["is_fraud"]

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, Y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model.score(X,Y)
# Out:
# 0.9999984575934602

# %%
model2 = DecisionTreeClassifier(random_state=42)
model2.fit(X, Y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
model2.score(X,Y)
# Out:
# 1.0

# %%
model3 = LogisticRegression(class_weight='balanced', C=0.01, max_iter=1000)
model3.fit(X, Y)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.01, class_weight='balanced', max_iter=1000)

# %%
model3.score(X,Y)
# Out:
# 0.8887369618447182

# %%
df1=pd.read_csv('fraudTest.csv')
df1.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df1.drop_duplicates()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df1['trans_date_trans_time'] = pd.to_datetime(df1['trans_date_trans_time'])

df1['dob'] = pd.to_datetime(df1['dob'])
df1['hour'] = df1['trans_date_trans_time'].dt.hour
df1['is_night'] = df1['hour'].apply(lambda x: 1 if x < 6 or x > 22 else 0)
df1['day_of_week'] = df1['trans_date_trans_time'].dt.dayofweek

# %%
df1.drop(columns=['Unnamed: 0','cc_num','first','last','street','city','state','zip','dob','unix_time','trans_num'],
        inplace=True)
df1.head(5)
# Out:
#   trans_date_trans_time                              merchant        category  \
# 0   2020-06-21 12:14:25                 fraud_Kirlin and Sons   personal_care
# 1   2020-06-21 12:14:33                  fraud_Sporer-Keebler   personal_care
# 2   2020-06-21 12:14:53  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3   2020-06-21 12:15:15                     fraud_Haley Group        misc_pos
# 4   2020-06-21 12:15:17                 fraud_Johnston-Casper          travel
#
#      amt gender      lat      long  city_pop                     job  \
# 0   2.86      M  33.9659  -80.9355    333497     Mechanical engineer
# 1  29.84      F  40.3207 -110.4360       302  Sales professional, IT
# 2  41.28      F  40.6729  -73.5365     34496       Librarian, public
# 3  60.05      M  28.5697  -80.8191     54767            Set designer
# 4   3.19      M  44.2529  -85.0170      1126      Furniture designer
#
#    merch_lat  merch_long  is_fraud  hour  is_night  day_of_week
# ...

# %%
def distance(row):
    return haversine((row['lat'], row['long']), (row['merch_lat'], row['merch_long']))

df1['distance'] = df1.apply(distance, axis=1)
df1.drop(['trans_date_trans_time','lat', 'long', 'merch_lat', 'merch_long'], axis=1, inplace=True)

# %%
le = LabelEncoder()
df1['category'] = le.fit_transform(df1['category'])
df1['gender'] = le.fit_transform(df1['gender'])
df1['merchant'] = le.fit_transform(df1['merchant'])
df1['job'] = le.fit_transform(df1['job'])

# %%
X_test = df1.drop(columns=["is_fraud"], inplace = False)
Y_test = df1["is_fraud"]

# %%
print("Model : Random Forest")
if Y_test is not None:

    y_pred = model.predict(X_test)
    print("Accuracy:", accuracy_score(Y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
    print("Classification Report\n",classification_report(Y_test, y_pred))
else:
    predictions = model.predict(X_test)
    print(predictions[:10])
# Out:
# Model : Random Forest
# Accuracy: 0.9983966716991861
# Confusion Matrix:
#  [[553371    203]
#  [   688   1457]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.88      0.68      0.77      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.94      0.84      0.88    555719
# weighted avg       1.00      1.00      1.00    555719

# %%
print("Model3 : Decision Tree")
if Y_test is not None:

    y_pred = model2.predict(X_test)
    print("Accuracy:", accuracy_score(Y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
    print("Classification Report:\n",classification_report(Y_test, y_pred))
else:
    predictions = model2.predict(X_test)
    print(predictions[:10])
# Out:
# Model3 : Decision Tree
# Accuracy: 0.9970884565760754
# Confusion Matrix:
#  [[552596    978]
#  [   640   1505]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.61      0.70      0.65      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.80      0.85      0.82    555719
# weighted avg       1.00      1.00      1.00    555719

# %%
print("Model3 : Logistic Regression")
if Y_test is not None:

    y_pred = model3.predict(X_test)
    print("Accuracy:", accuracy_score(Y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
    print("Classification Report:\n",classification_report(Y_test, y_pred))
else:
    predictions = model3.predict(X_test)
    print(predictions[:10])
# Out:
# Model3 : Logistic Regression
# Accuracy: 0.879284314554658
# Confusion Matrix:
#  [[486987  66587]
#  [   497   1648]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94    553574
#            1       0.02      0.77      0.05      2145
#
#     accuracy                           0.88    555719
#    macro avg       0.51      0.82      0.49    555719
# weighted avg       1.00      0.88      0.93    555719
